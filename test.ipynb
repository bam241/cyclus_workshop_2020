# %%
import pandas as pd
import numpy as np

from cymetric import graphs as cgr
from cymetric import timeseries as tm
import cymetric as cym

# %%
file = "cyclus.sqlite"
ev = cym.Evaluator(cym.dbopen(file), write=False)

# %%
cgr.flow_graph(ev)
